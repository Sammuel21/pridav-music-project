# %% [markdown]
# ## Spotify API Data Analysis
#
# This is analysis aims to explore and process production-like data from the spotify API, create blueprints for data processing,
# sample will match the full population.

# %%
import os
import sys

sys.dont_write_bytecode = True

import requests
import json
import time
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from dotenv import load_dotenv

load_dotenv()
# Out:
# False

# %% [markdown]
# Loading input data harvested by Natalia Krebesova from the public official Spotify data API.

# %%
data = pd.read_csv('./Data/spotify_tracks.csv')

# %%
data.head()
# Out:
#                        id                name  track_number  disc_number  \
# 0  3d9DChrdc6BOeFsbrZ3Is0    Under the Bridge            11            1
# 1  6sy3LkhNFjJWlaeSMNwQ62      Counting Stars             1            1
# 2  5YJtMNWKe55yr49cyJgxva  Everytime We Touch             1            1
# 3  27AHAtAirQapVldIm4c9ZX                Jump             2            1
# 4  5G1sTBGbZT5o4PNRc75RKI          Lonely Boy             1            1
#
#    duration_ms  popularity  explicit                artists  \
# 0       264306          81     False  Red Hot Chili Peppers
# 1       257840          71     False            OneRepublic
# 2       197124          72     False                Cascada
# 3       195106          64     False             Kris Kross
# 4       193653          68     False         The Black Keys
#
#                artist_ids                                   album  \
# 0  0L8ExT028jH3ddEcZwqJJ5  Blood Sugar Sex Magik (Deluxe Edition)
# 1  5Pwc4xIPtQLFEnJriah9YJ                                  Native
# 2  0N0d3kjwdY2h7UVuTdJGfp    Everytime We Touch (Premium Edition)
# 3  2zrZfs23sjuHDv4E6YRmNf                     Totally Krossed Out
# 4  7mnBLXK823vNxN3UWB7Gfz                               El Camino
#
#    album_total_tracks          album_artists        album_artist_ids  \
# 0                  19  Red Hot Chili Peppers  0L8ExT028jH3ddEcZwqJJ5
# 1                  15            OneRepublic  5Pwc4xIPtQLFEnJriah9YJ
# 2                  45                Cascada  0N0d3kjwdY2h7UVuTdJGfp
# 3                  15             Kris Kross  2zrZfs23sjuHDv4E6YRmNf
# 4                  11         The Black Keys  7mnBLXK823vNxN3UWB7Gfz
#
#   album_release_date  restrictions  \
# 0         1991-09-24           NaN
# 1         2014-01-01           NaN
# 2         2010-02-12           NaN
# 3         1992-03-17           NaN
# 4         2011-12-06           NaN
#
#                                    available_markets
# 0  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 1  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 2  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 3  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# 4  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...

# %% [markdown]
# NOTE:
#
# After further consultation with the team we have decided that this data from official Spotify API might not be the best for the purposes of data analyses
# and modelling, hence we will use other data - specifically, data from Kaggle which were used in the first introductory analyses could be a great candidate
# since this data contains acustic data features which is important for modelling purposes.
#
# ___

# %% [markdown]
# ### Other data source exploration
#
# These datasets are candidates for project source data:
# - https://www.kaggle.com/datasets/gauthamvijayaraj/spotify-tracks-dataset-updated-every-week

# %% [markdown]
# #### weekly-update dataset
#
# This dataset contains data about ~ 60 000 tracks, accordidng to the data documentation on Kaggle it supports 6 different languages, hence an analysis
# of duplicates is needed to determine whether these tracks are duplicates in different languages or are unique songs sang in different languages.

# %%
data = pd.read_csv('./Data/spotify_tracks_kaggle_weekly.csv')

# %%
data.shape
# Out:
# (62317, 22)

# %% [markdown]
# Attribute quick analysis - what kind of data are we dealing with?
#
# - track_id : unique ID for songs -> PK
# - track_url : combination of spotify endpoint + track_id -> another PK but ID is enough
# - others seem to be normal data attributes

# %%
data.head()
# Out:
#                  track_id                                  track_name  \
# 0  2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1  4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2  59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3  5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4  1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
#
#                                          artist_name  year  popularity  \
# 0                                Anirudh Ravichander  2024          59
# 1  Anirudh Ravichander, Pravin Mani, Vaishali Sri...  2024          47
# 2           Anirudh Ravichander, Anivee, Alvin Bruno  2024          35
# 3  Anirudh Ravichander, Bharath Sankar, Kabilan, ...  2024          24
# 4  Anirudh Ravichander, Benny Dayal, Leon James, ...  2024          22
#
#                                          artwork_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273ce9c65...
# 1  https://i.scdn.co/image/ab67616d0000b273be1b03...
# 2  https://i.scdn.co/image/ab67616d0000b27334a1dd...
# 3  https://i.scdn.co/image/ab67616d0000b27332e623...
# 4  https://i.scdn.co/image/ab67616d0000b2735a59b6...
#
#                                    album_name  acousticness  danceability  \
# 0                  Leo Das Entry (From "Leo")        0.0241         0.753
# 1                                AAO KILLELLE        0.0851         0.780
# 2      Mayakiriye Sirikiriye (Orchestral EDM)        0.0311         0.457
# 3    Scene Ah Scene Ah (Experimental EDM Mix)        0.2270         0.718
# 4  Gundellonaa X I Am a Disco Dancer (Mashup)        0.0153         0.689
#
#    duration_ms  ...   key  liveness  loudness  mode  speechiness    tempo  \
# 0      97297.0  ...   8.0    0.1000    -5.994   0.0       0.1030  110.997
# 1     207369.0  ...  10.0    0.0951    -5.674   0.0       0.0952  164.995
# 2      82551.0  ...   2.0    0.0831    -8.937   0.0       0.1530  169.996
# 3     115831.0  ...   7.0    0.1240   -11.104   1.0       0.4450  169.996
# 4     129621.0  ...   7.0    0.3450    -9.637   1.0       0.1580  128.961
#
#    time_signature  valence                                          track_url  \
# 0             4.0    0.459  https://open.spotify.com/track/2r0ROhr7pRN4MXD...
# 1             3.0    0.821  https://open.spotify.com/track/4I38e6Dg52a2o2a...
# 2             4.0    0.598  https://open.spotify.com/track/59NoiRhnom3lTeR...
# 3             4.0    0.362  https://open.spotify.com/track/5uUqRQd385pvLxC...
# 4             4.0    0.593  https://open.spotify.com/track/1KaBRg2xgNeCljm...
#
#    language
# 0     Tamil
# 1     Tamil
# 2     Tamil
# 3     Tamil
# 4     Tamil
#
# [5 rows x 22 columns]

# %% [markdown]
# Duplicate count based on track id -> this should eliminate language barier, ID serves as unique key for songs

# %%
data['track_id'].duplicated().sum()
# Out:
# 78

# %%
data[data['track_id'].duplicated(keep=False)].sort_values(by='track_id')
# Out:
#                     track_id                                    track_name  \
# 2494  08elXSPBnP9uFYkjpObT5T      Yaaro Ucchikilai Meley (From "Taramani")
# 2572  08elXSPBnP9uFYkjpObT5T      Yaaro Ucchikilai Meley (From "Taramani")
# 2432  0A0fukU8m9V1DHzzIOFUHq                  Ye Rasa - From "MaaManithan"
# 2510  0A0fukU8m9V1DHzzIOFUHq                  Ye Rasa - From "MaaManithan"
# 2491  0DqKN7Wg0lsQaf6MuaREpX                          Munnala Ninna Pothum
# ...                      ...                                           ...
# 2506  7rto8ANj8esy1YSfDekGSL  Valimai Motion Poster Theme (From "Valimai")
# 2489  7t89o04EbT4flij8QFYGuK                      Super Deluxe (BGM Cover)
# 2567  7t89o04EbT4flij8QFYGuK                      Super Deluxe (BGM Cover)
# 2538  7uihm93NAp8PWqyn1wn4OB                             Glance of Rukmani
# 2460  7uihm93NAp8PWqyn1wn4OB                             Glance of Rukmani
#
#                                      artist_name  year  popularity  \
# 2494                          Yuvan Shankar Raja  2020           0
# 2572                          Yuvan Shankar Raja  2020           0
# 2432  Yuvan Shankar Raja, Ilayaraaja, U1 Records  2021          35
# 2510  Yuvan Shankar Raja, Ilayaraaja, U1 Records  2021          35
# 2491     Yuvan Shankar Raja, Saindhavi, Sunandan  2020           4
# ...                                          ...   ...         ...
# 2506                          Yuvan Shankar Raja  2021          34
# 2489                          Yuvan Shankar Raja  2020          20
# 2567                          Yuvan Shankar Raja  2020          20
# 2538          Yuvan Shankar Raja, Vivek - Mervin  2021           5
# 2460          Yuvan Shankar Raja, Vivek - Mervin  2021           5
#
#                                             artwork_url  \
# 2494  https://i.scdn.co/image/ab67616d0000b27320428b...
# 2572  https://i.scdn.co/image/ab67616d0000b27320428b...
# 2432  https://i.scdn.co/image/ab67616d0000b2738bc6a0...
# 2510  https://i.scdn.co/image/ab67616d0000b2738bc6a0...
# 2491  https://i.scdn.co/image/ab67616d0000b2734ae5bd...
# ...                                                 ...
# 2506  https://i.scdn.co/image/ab67616d0000b2733a8f59...
# 2489  https://i.scdn.co/image/ab67616d0000b273992681...
# 2567  https://i.scdn.co/image/ab67616d0000b273992681...
# 2538  https://i.scdn.co/image/ab67616d0000b273e3d93e...
# 2460  https://i.scdn.co/image/ab67616d0000b273e3d93e...
#
#                                         album_name  acousticness  \
# 2494                                   U1 For Life        0.0217
# 2572                                   U1 For Life        0.0217
# 2432                  Ye Rasa (From "MaaManithan")        0.7260
# 2510                  Ye Rasa (From "MaaManithan")        0.7260
# 2491                                     Dabangg 3        0.2700
# ...                                            ...           ...
# 2506  Valimai Motion Poster Theme (From "Valimai")        0.3060
# 2489                      Super Deluxe (BGM Cover)        0.3250
# 2567                      Super Deluxe (BGM Cover)        0.3250
# 2538           Sulthan (Original Background Score)        0.7880
# 2460           Sulthan (Original Background Score)        0.7880
#
#       danceability  duration_ms  ...  key  liveness  loudness  mode  \
# 2494         0.643     177867.0  ...  8.0    0.1460    -5.697   0.0
# 2572         0.643     177867.0  ...  8.0    0.1460    -5.697   0.0
# 2432         0.702     242659.0  ...  9.0    0.0731    -7.922   1.0
# 2510         0.702     242659.0  ...  9.0    0.0731    -7.922   1.0
# 2491         0.496     246625.0  ...  9.0    0.1390    -3.419   1.0
# ...            ...          ...  ...  ...       ...       ...   ...
# 2506         0.722      87600.0  ...  8.0    0.0546    -8.597   1.0
# 2489         0.361      66130.0  ...  3.0    0.1100    -8.770   0.0
# 2567         0.361      66130.0  ...  3.0    0.1100    -8.770   0.0
# 2538         0.544      50583.0  ...  5.0    0.0807    -9.090   0.0
# 2460         0.544      50583.0  ...  5.0    0.0807    -9.090   0.0
#
#       speechiness    tempo  time_signature  valence  \
# 2494       0.0510  179.991             4.0    0.509
# 2572       0.0510  179.991             4.0    0.509
# 2432       0.0323  125.990             3.0    0.412
# 2510       0.0323  125.990             3.0    0.412
# 2491       0.1120  128.921             4.0    0.848
# ...           ...      ...             ...      ...
# 2506       0.0748  100.032             4.0    0.596
# 2489       0.0330  158.910             3.0    0.238
# 2567       0.0330  158.910             3.0    0.238
# 2538       0.0799  143.750             4.0    0.923
# 2460       0.0799  143.750             4.0    0.923
#
#                                               track_url  language
# 2494  https://open.spotify.com/track/08elXSPBnP9uFYk...     Tamil
# 2572  https://open.spotify.com/track/08elXSPBnP9uFYk...     Tamil
# 2432  https://open.spotify.com/track/0A0fukU8m9V1DHz...     Tamil
# 2510  https://open.spotify.com/track/0A0fukU8m9V1DHz...     Tamil
# 2491  https://open.spotify.com/track/0DqKN7Wg0lsQaf6...     Tamil
# ...                                                 ...       ...
# 2506  https://open.spotify.com/track/7rto8ANj8esy1YS...     Tamil
# 2489  https://open.spotify.com/track/7t89o04EbT4flij...     Tamil
# 2567  https://open.spotify.com/track/7t89o04EbT4flij...     Tamil
# 2538  https://open.spotify.com/track/7uihm93NAp8PWqy...     Tamil
# 2460  https://open.spotify.com/track/7uihm93NAp8PWqy...     Tamil
#
# [156 rows x 22 columns]

# %% [markdown]
# duplicate count against all attributes

# %%
data.duplicated().sum()
# Out:
# 78

# %% [markdown]
# No data anomalies present since ID duplicate count == row duplicate count, this data can be dropped.

# %%
processed_data = data.drop_duplicates()

# %%
processed_data.sort_values(by='popularity')
# Out:
#                      track_id  \
# 31197  7wFbKKM7TXNwj1SWBe4vz7
# 38685  6gPaEqLowtl4Q3X6geC8cy
# 38686  3LmyzTgiIkQgNxbyjc6RUN
# 38687  2KOl72TPOjfROBtBdQmRiJ
# 38689  1mBSAPdKwtfBR9OWJm184x
# ...                       ...
# 24273  4R2kfaDFhslZEMJqAFNpdd
# 54962  62bOmKYxYg7dhrC6gH9vFn
# 26432  0VjIjW4GlUZAMYd2vXMi3b
# 26580  7MXVkk9YMctZqd1Srtv4MB
# 49479  0OA00aPt3BV10qeMIs3meW
#
#                                               track_name  \
# 31197                                          Actuality
# 38685                             Yen Ooru Madura, Pt. 2
# 38686                      Padikavandhadhu - Male Vocals
# 38687                                   Chinna Roja Ival
# 38689                                 Manasu Thudikkuthu
# ...                                                  ...
# 24273                                           cardigan
# 54962  Bye Bye Bye - From Deadpool and Wolverine Soun...
# 26432                                    Blinding Lights
# 26580                                            Starboy
# 49479                                          Big Dawgs
#
#                  artist_name  year  popularity  \
# 31197                  Twice  2016           0
# 38685                   Deva  1992           0
# 38686  Deva, Mano, Kalidasan  1992           0
# 38687   Deva, Vasan, Sujatha  1992           0
# 38689    Deva, K. S. Chithra  1992           0
# ...                      ...   ...         ...
# 24273           Taylor Swift  2020          89
# 54962                 *NSYNC  2000          90
# 26432             The Weeknd  2020          91
# 26580  The Weeknd, Daft Punk  2016          91
# 49479     Hanumankind, Kalmi  2024          93
#
#                                              artwork_url  \
# 31197  https://i.scdn.co/image/ab67616d0000b2739c03ee...
# 38685  https://i.scdn.co/image/ab67616d0000b273ea9df4...
# 38686  https://i.scdn.co/image/ab67616d0000b2731cec4d...
# 38687  https://i.scdn.co/image/ab67616d0000b273146768...
# 38689  https://i.scdn.co/image/ab67616d0000b27329f84a...
# ...                                                  ...
# 24273  https://i.scdn.co/image/ab67616d0000b27395f754...
# 54962  https://i.scdn.co/image/ab67616d0000b273a6cb8f...
# 26432  https://i.scdn.co/image/ab67616d0000b2738863bc...
# 26580  https://i.scdn.co/image/ab67616d0000b2734718e2...
# 49479  https://i.scdn.co/image/ab67616d0000b273d9afe5...
#
#                                               album_name  acousticness  \
# 31197                                          Actuality       0.05920
# 38685  Vaasalil Oru Vennila (Original Motion Picture ...       0.85000
# 38686   En Rajangam (Original Motion Picture Soundtrack)       0.43500
# 38687  Manasukkul Varalama (Original Motion Picture S...       0.37300
# 38689  Kavalukku Kannellai (Original Motion Picture S...       0.75400
# ...                                                  ...           ...
# 24273                                           folklore       0.53700
# 54962                                No Strings Attached       0.03100
# 26432                                        After Hours       0.00146
# 26580                                            Starboy       0.14100
# 49479                                          Big Dawgs       0.02350
#
#        danceability  duration_ms  ...  key  liveness  loudness  mode  \
# 31197         0.212     270493.0  ...  9.0    0.3640    -6.907   1.0
# 38685         0.591     306307.0  ...  4.0    0.3810    -6.245   0.0
# 38686         0.600     285525.0  ...  9.0    0.0552    -6.956   1.0
# 38687         0.643     281800.0  ...  8.0    0.3630    -7.761   1.0
# 38689         0.580     240466.0  ...  1.0    0.1930   -10.207   1.0
# ...             ...          ...  ...  ...       ...       ...   ...
# 24273         0.613     239560.0  ...  0.0    0.2500    -8.588   0.0
# 54962         0.610     200400.0  ...  8.0    0.0821    -4.843   0.0
# 26432         0.514     200040.0  ...  1.0    0.0897    -5.934   1.0
# 26580         0.679     230453.0  ...  7.0    0.1370    -7.015   1.0
# 49479         0.464     190667.0  ...  4.0    0.3630    -3.202   0.0
#
#        speechiness    tempo  time_signature  valence  \
# 31197       0.0554  123.948             4.0    0.351
# 38685       0.0383   86.688             4.0    0.798
# 38686       0.3300   66.408             4.0    0.833
# 38687       0.0427  101.067             4.0    0.444
# 38689       0.0735  118.496             4.0    0.803
# ...            ...      ...             ...      ...
# 24273       0.0424  130.033             4.0    0.551
# 54962       0.0479  172.638             4.0    0.861
# 26432       0.0598  171.005             4.0    0.334
# 26580       0.2760  186.003             4.0    0.486
# 49479       0.1610  180.098             4.0    0.262
#
#                                                track_url  language
# 31197  https://open.spotify.com/track/7wFbKKM7TXNwj1S...    Korean
# 38685  https://open.spotify.com/track/6gPaEqLowtl4Q3X...     Tamil
# 38686  https://open.spotify.com/track/3LmyzTgiIkQgNxb...     Tamil
# 38687  https://open.spotify.com/track/2KOl72TPOjfROBt...     Tamil
# 38689  https://open.spotify.com/track/1mBSAPdKwtfBR9O...     Tamil
# ...                                                  ...       ...
# 24273  https://open.spotify.com/track/4R2kfaDFhslZEMJ...   English
# 54962  https://open.spotify.com/track/62bOmKYxYg7dhrC...   English
# 26432  https://open.spotify.com/track/0VjIjW4GlUZAMYd...   English
# 26580  https://open.spotify.com/track/7MXVkk9YMctZqd1...   English
# 49479  https://open.spotify.com/track/0OA00aPt3BV10qe...   English
#
# [62239 rows x 22 columns]

# %% [markdown]
# Duplicate analysis - completed, onto the anomaly analysis

# %% [markdown]
# **Data type analysis**

# %%
categorical_columns = processed_data.dtypes[processed_data.dtypes == object].index
numerical_columns = processed_data.dtypes[processed_data.dtypes != object].index

# %% [markdown]
# inspection of categorical columns - there seems to be no anomaly in numerical columns which would force recast to categorical dtype

# %% [markdown]
# Besides anomaly detection, these columns can be included in drop list as they serve as identifiers:
# - track_name : ID like attribute
# - artwork_url : not important for analytical results
# - track_url : not important for analytical results

# %%
processed_data[categorical_columns]
# Out:
#                      track_id                                  track_name  \
# 0      2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1      4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2      59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3      5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4      1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
# ...                       ...                                         ...
# 62312  3eHDwMQYPEziy2DWRBNoLv                        Sani - G.O.A.T Remix
# 62313  5hHtCqkNv5eo99OrEFFcgS                            Life of Bachelor
# 62314  08foF9YHgKmIgOy3xMWRZy                                     Yo Baby
# 62315  2wLFbVlQGKJSd9lwzwL47F                           Fast Fast Vadiley
# 62316  5OYxwYeFfumMTAoAdVeet3             Moonu Moonu Moonu (From "3:33")
#
#                                              artist_name  \
# 0                                    Anirudh Ravichander
# 1      Anirudh Ravichander, Pravin Mani, Vaishali Sri...
# 2               Anirudh Ravichander, Anivee, Alvin Bruno
# 3      Anirudh Ravichander, Bharath Sankar, Kabilan, ...
# 4      Anirudh Ravichander, Benny Dayal, Leon James, ...
# ...                                                  ...
# 62312  Arvind Raj, Sheezay, Music Kitchen, FSPROD Vin...
# 62313  A H Kaashif, Navakkarai Naveen Prabanjam, Asal...
# 62314         Rakesh Ambigapathy, Asal Kolaar, MC Vickey
# 62315          Asal Kolaar, Priyadarshan Balasubramanian
# 62316  Harshavardhan Rameshwar, G. V. Prakash, Dharma...
#
#                                              artwork_url  \
# 0      https://i.scdn.co/image/ab67616d0000b273ce9c65...
# 1      https://i.scdn.co/image/ab67616d0000b273be1b03...
# 2      https://i.scdn.co/image/ab67616d0000b27334a1dd...
# 3      https://i.scdn.co/image/ab67616d0000b27332e623...
# 4      https://i.scdn.co/image/ab67616d0000b2735a59b6...
# ...                                                  ...
# 62312  https://i.scdn.co/image/ab67616d0000b273819d23...
# 62313  https://i.scdn.co/image/ab67616d0000b2736cd651...
# 62314  https://i.scdn.co/image/ab67616d0000b27300da25...
# 62315  https://i.scdn.co/image/ab67616d0000b273e051e1...
# 62316  https://i.scdn.co/image/ab67616d0000b273efd671...
#
#                                           album_name  \
# 0                         Leo Das Entry (From "Leo")
# 1                                       AAO KILLELLE
# 2             Mayakiriye Sirikiriye (Orchestral EDM)
# 3           Scene Ah Scene Ah (Experimental EDM Mix)
# 4         Gundellonaa X I Am a Disco Dancer (Mashup)
# ...                                              ...
# 62312                           Sani (G.O.A.T Remix)
# 62313  Bachelor (Original Motion Picture Soundtrack)
# 62314                                        Yo Baby
# 62315                                Arjuna Phalguna
# 62316                Moonu Moonu Moonu (From "3:33")
#
#                                                track_url language
# 0      https://open.spotify.com/track/2r0ROhr7pRN4MXD...    Tamil
# 1      https://open.spotify.com/track/4I38e6Dg52a2o2a...    Tamil
# 2      https://open.spotify.com/track/59NoiRhnom3lTeR...    Tamil
# 3      https://open.spotify.com/track/5uUqRQd385pvLxC...    Tamil
# 4      https://open.spotify.com/track/1KaBRg2xgNeCljm...    Tamil
# ...                                                  ...      ...
# 62312  https://open.spotify.com/track/3eHDwMQYPEziy2D...    Tamil
# 62313  https://open.spotify.com/track/5hHtCqkNv5eo99O...    Tamil
# 62314  https://open.spotify.com/track/08foF9YHgKmIgOy...    Tamil
# 62315  https://open.spotify.com/track/2wLFbVlQGKJSd9l...    Tamil
# 62316  https://open.spotify.com/track/5OYxwYeFfumMTAo...    Tamil
#
# [62239 rows x 7 columns]
